# %% [markdown]
# <h1 style="text-align: center; font-family: 'Arial', sans-serif; color: #2c3e50;">Linear Regression In-Class Project</h1>
#
# <h2 style="font-family: 'Georgia', serif; color: #2980b9;">Instructions</h2>
#
# <p style="font-family: 'Georgia', serif;">
#     In this project, you will explore some of the mathematics of linear regression step-by-step. We will work through different cases of fitting lines to data and understand how linear regression works for different data sets. You'll work with Python for coding, and we'll also use whiteboards for derivations and practice with partial derivatives.
# </p>
#
# <p style="font-family: 'Georgia', serif; font-style: italic;">Be sure you have markers to use on the whiteboard. Note that there are <b>four</b> parts: be sure you time yourself and not spend too much time on the early parts of this ICA.</p>
#
# <p style="font-family: 'Georgia', serif;">You will turn in one notebook with the names of people in your group.</p>
#
# <h3 style="font-family: 'Georgia', serif; color: #16a085;">Goals for this ICA:</h3>
# <ol style="font-family: 'Georgia', serif;">
#     <li>Derive the slope w<sub>1</sub> and intercept w<sub>0</sub> for linear regression with two data points.</li>
#     <li>Extend the method to cases where we have fewer or more than two data points.</li>
#     <li>Practice the use of partial derivatives to minimize a loss function and optimize the fit of a line to multiple features.</li>
#     <li>Compare one-dimensional and two-dimensional linear regression problems.</li>
# </ol>
#
# <hr style="border: 1px solid #2980b9;">
#
# <h3 style="font-family: 'Georgia', serif; color: #e74c3c;">Part 1: Simple 1D Linear Regression</h3>
#
# <p style="font-family: 'Georgia', serif;">
#     We are working with the model equation for linear regression,
# </p>
#
# <p style="text-align: center; font-family: 'Georgia', serif; font-size: 18px;">
#     y = w<sub>0</sub> + w<sub>1</sub>  x,
# </p>
#
# <p style="font-family: 'Georgia', serif;">
# where
# </p>
#
# <ul style="font-family: 'Georgia', serif;">
#     <li>w<sub>0</sub> is the intercept of the line (the point where it crosses the y-axis).</li>
#     <li>w<sub>1</sub> is the slope of the line (how steep the line is).</li>
#     <li>x is the independent variable.</li>
#     <li>y is the dependent variable (the value we predict).</li>
# </ul>
#
# <p style="font-family: 'Georgia', serif;">Let's calculate w<sub>0</sub> and w<sub>1</sub> based on two points and then plot the regression line.</p>

# %% [markdown]
# <h4 style="font-family: 'Georgia', serif; color: #1a719a;">Simple 1D Linear Regression with Two Data Points</h4>
#
# We are given two data points:
#
# $$ (x_1, y_1) = (1, 2) $$
#
# and
#
# $$ (x_2, y_2) = (3, 3). $$
#
# For any given two points, derive on the whiteboard the general slope $w_1$ and intercept $w_0$ of the line that fits these two points:
#
# $$ w_1 = ??? ,$$
#
# $$ w_0 = ??? .$$
#
# The slope $w_1$ tells us how steep the line is, and the intercept $w_0$ gives us the point where the line crosses the y-axis.
#
# After deriving $w_0$ and $w_1$, we can use the two given points to compute precise values for this case, plot the line and visualize it along with the data points. Plot the data and the line using the derived values for $w_0$ and $w_1$ in a code cell below.
#
# **Turn in a photo of the whiteboard your group used; show all of your work.**
#
# Comment on how well the regression line fits the data. How well does the line fit the data? Does the line go through the data point? Why or why not?

# %% [markdown]
# <hr style="border: 1px solid #2980b9;">
#
# <h3 style="font-family: 'Georgia', serif; color: #e74c3c;">Part 2: Cases with One or Three (or More) Data Points</h3>
#
#
#
# We just practiced fitting a line to two points; now, in this step, we'll explore what happens in two new cases:
# 1. **Case 1:** Fitting a line to only one data point.
# 2. **Case 2:** Fitting a line to three or more data points.
#
# Once we can do these two new cases, we have all cases covered!
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Case 1: One Data Point</h5>
#
# For the case of one data point, derive the equations for the regression line.  Use the first point given above.
#
#
#
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Whiteboard Exercise:</h5>
#
# 1. **Discuss and derive**: Take a moment to write down your derivation on the whiteboard and discuss with your group. What do you expect to happen when trying to fit a line through just one point?
# 2. **Draw the situation**: On the whiteboard, draw the scenario with just one data point and discuss whether it's possible to determine both the slope ($w_1$) and intercept ($w_0$) of a line.
# 3. **Key Insight**: For one data point, we ???.
#
# Document your results.
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Case 2: Three or More Data Points</h5>
#
#
# Next, let's consider the case of having three or more data points. Use the two points given above and add a third between them.
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Whiteboard Exercise:</h5>
#
# 1. **Discuss and derive**: Take a few minutes to talk about what changes when we have more than two data points. What might happen when we try to fit a line to these points? How is this different from one point?
# 2. **Draw the situation**: On the whiteboard, draw three or more points on a 2D plot and discuss how a line might fit them. What did you do in the previous HW for this case? Discuss.
# 3. **Key Insight**: In general, ???.
#
# Write a discussion on your findings and conclusions, including a photo of the equations you used on your whiteboard. (If you are very organized on the whiteboard, you can include everything from this section in one photo.) Include in your discussion what you would do for $4$ points, $5$ points, and so on. Generally, datasets have a lot of data points and our models have a small number of parameters (weights); here, we only have two: $w_0$ and $w_1$.
#
# _____
#
# If you need some guidance about what to write about, consider these questions:
#
# ##### For One Data Point:
#
# * Why can't we determine both $w_0$ and $w_1$?
# * What happens if we try to fit a line through just one point?
# * What does it mean for the slope if we only have one point?
#
# ##### For Three or More Data Points:
#
# * What do we do when we can’t fit a line through all points perfectly?
# * When do we want the model to go through all points perfectly and not?
#
# ______

# %% [markdown]
# <hr style="border: 1px solid #2980b9;">
#
# <h3 style="font-family: 'Georgia', serif; color: #e74c3c;">Part 3: Use of the Loss Function in Linear Regression</h3>
#
# So far we have derived mathematical expressions for the parameters (weights) $w_i$ in our model. There is something you might have noticed: for datasets with many samples (above this meant $3$ or more), this becomes fairly awkward. We started with two equations in two unknowns, and that worked fine. When we had one datapoint, perhaps things didn't work out so well. Then, with three datapoints or more it wasn't clear how to proceed. We could have added another parameter, which would have resulted in three equations in three unknowns. While that works, you probably don't want to do this for datasets with a million samples! (_Or.....do you....???_)
#
# Next, we'll explore how to handle the case of three or more data points mathematically using a _loss function_ and _optimization_. This function will allow us to measure how well the line fits the data and minimize the error. And, importantly, we will see that it works in nearly every case.

# %% [markdown]
# When we fit a line to data using linear regression, we aim to minimize the error between the predicted values from our model and the actual data points. This error is captured by the _loss function_. This technique is extremely valuable in that it allows one to handle the case where there are many more data points than there are parameters in the model: this is the most common case in data science.
#
# The case in which there are fewer data points than parameters (the case above with two parameters $w_0$ and $w_1$ and one data point) can be handled; it is a bit subtle, so let's ignore it for now.
#
#
#
# <h4 style="font-family: 'Georgia', serif; color: #1a719a;">The Standard Loss Function</h4>
#
#
# For linear regression, the most commonly used loss function is the **sum of squared errors (SSE)**:
#
# $$ L(w_0, w_1) = \sum_{i=1}^{n} \left( y_i - (w_0 + w_1  x_i) \right)^2, $$
#
# where:
# - $i$ is the index for summing over all data points
# - $n$ is the number of data points,
# - $y_i$ are the actual values of the dependent variable,
# - $w_0 + w_1 x_i$ is the predicted value from our model,
# - $L(w_0, w_1)$ is the total error we want to minimize.
#
# Minimizing the squared error gives us a best-fit line that balances the error across all points. The goal is to find the values of $w_0$ and $w_1$ that make the loss function as small as possible. In general, how many variables will the loss function depend on?
#
# <h4 style="font-family: 'Georgia', serif; color: #1a719a;">Partial Derivatives</h4>
#
#
# To minimize the loss function, we take _partial derivatives_ with respect to $w_0$ and $w_1$ and set them to zero. This gives us the conditions that must be satisfied for the error to be minimized.
#
# Discuss _partial derivatives_ in your group. If someone knows about them, have that person (or people) teach the idea to the students for whom this is a new idea. If you haven't used or seen partial derivatives, *speak up*. This is your chance to get clear on these. Here are some ideas to guide you:
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Whiteboard Exercise: Practice with Normal Derivatives</h5>
#
# Let's first practice taking the derivative of a simple 1D parabola:
#
# $$ f(x) = x^2 $$
#
# **Step 1:** Write down and solve for the derivative of $f(x)$. What is $ \frac{df}{dx} $?
#
# **Step 2:** Plot the parabola and find the point where the slope is zero (this is the minimum of the function).
#
#
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Whiteboard Exercise: Practice with Partial Derivatives</h5>
#
# Next, let's extend this to the two-variable case by considering:
#
# $$ f(w_0, w_1) = (w_0 - 2)^2 + w_1^2 $$
#
# **Step 1:** Take the partial derivatives with respect to $w_0$ and $w_1$. What are $ \frac{\partial f}{\partial w_0} $ and $ \frac{\partial f}{\partial w_1}$? Where is the minimum of $f(w_0, w_1)$?
#
# **Step 2:** Discuss how minimizing with two variables is different from one and why partial derivatives are necessary.
#
# **Step 3:** Write out, on the whiteboard, the loss function for the cases $n=1$, $n=2$ and $n=3$; are there issues and/or limitations?
# - Take the partial derivatives of this expression.
# - Describe what you find and include all steps of your derivation either in $\LaTeX$ or by taking a picture of your whiteboard.
# - Confirm that everyone in your group understands every step before continuing.

# %% [markdown]
# <hr style="border: 1px solid #2980b9;">
#
# <h3 style="font-family: 'Georgia', serif; color: #e74c3c;">Part 4: Visualizing the Loss Function</h3>
#
# Let's explore what these partial derivatives are doing. This can be visualized with the loss function $L(w_0,w_1)$ shown in the 2D space of parameters $(w_0,w_1)$ it depends on. Let's take a look at it. Be sure your group understands this code.

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Define a simple dataset with three points (x, y)
x_data = np.array([1, 2, 3])
y_data = np.array([2, 3, 5])

# Define the loss function (sum of squared errors)
def loss_function(w0, w1, x, y):
    return np.sum((y - (w0 + w1 * x))**2)

# Create a grid of w0 and w1 values for visualization
w0_vals = np.linspace(-5, 5, 100)
w1_vals = np.linspace(-5, 5, 100)
W0, W1 = np.meshgrid(w0_vals, w1_vals)

# Calculate the loss for each combination of w0 and w1
Z = np.array([[loss_function(w0, w1, x_data, y_data) for w1 in w1_vals] for w0 in w0_vals])

# Plot the loss function surface
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(W0, W1, Z, cmap='viridis')
ax.set_title('Loss Function Surface: L(w0, w1)')
ax.set_xlabel('w0')
ax.set_ylabel('w1')
ax.set_zlabel('Loss')
plt.show()

# %% [markdown]
# When we find the minimum of this curve we are finding the optimal values of $w_0$ and $w_1$. At that minimum, the partial derivatives $\partial L/\partial w_i$ are both zero. That is, the loss function is **flat**: the derivatives in both directions are zero.

# %%
# Gradient descent function to minimize the loss function
def gradient_descent(x, y, w0_init, w1_init, learning_rate, num_iterations):
    w0, w1 = w0_init, w1_init
    m = len(y)
    for i in range(num_iterations):
        # Compute predictions
        y_pred = w0 + w1 * x
        # Calculate the gradients
        grad_w0 = (-2/m) * np.sum(y - y_pred)
        grad_w1 = (-2/m) * np.sum((y - y_pred) * x)
        # Update w0 and w1 using the gradients
        w0 -= learning_rate * grad_w0
        w1 -= learning_rate * grad_w1
        # Optionally print the progress
        if i % 100 == 0:
            print(f"Iteration {i}: w0 = {w0:.4f}, w1 = {w1:.4f}, loss = {loss_function(w0, w1, x, y):.4f}")
    return w0, w1

# Initial guess for w0 and w1
w0_init = 0
w1_init = 0
learning_rate = 0.01
num_iterations = 1000

# Perform gradient descent to find the optimal w0 and w1
optimal_w0, optimal_w1 = gradient_descent(x_data, y_data, w0_init, w1_init, learning_rate, num_iterations)

print(f"\nOptimal w0: {optimal_w0}, \nOptimal w1: {optimal_w1}")
# Out:
# Iteration 0: w0 = 0.0667, w1 = 0.1533, loss = 30.0785
# Iteration 100: w0 = 0.5479, w1 = 1.4056, loss = 0.1865
# Iteration 200: w0 = 0.5020, w1 = 1.4258, loss = 0.1789
# Iteration 300: w0 = 0.4659, w1 = 1.4417, loss = 0.1742
# Iteration 400: w0 = 0.4375, w1 = 1.4542, loss = 0.1713
# Iteration 500: w0 = 0.4153, w1 = 1.4640, loss = 0.1696
# Iteration 600: w0 = 0.3977, w1 = 1.4717, loss = 0.1685
# Iteration 700: w0 = 0.3840, w1 = 1.4777, loss = 0.1678
# Iteration 800: w0 = 0.3731, w1 = 1.4825, loss = 0.1673
# Iteration 900: w0 = 0.3646, w1 = 1.4862, loss = 0.1671
#
# Optimal w0: 0.3579829649416946,
# Optimal w1: 1.4891565847482928

# %% [markdown]
# As you can see, we can find the minimum of the loss function, which yields the "best" values of $w_0$ and $w_1$, using a numerical method that searches for the bottom. This might seem a bit more complicated than what you did at the beginning of this ICA where we just derived mathematical expressions. But, the numerical approach can be much better for complicated situations where we cannot derive simple expressions.
#
# Thus, you can see that partial derivatives have a very geometrical interpretation.
#
# Let's see if it worked:

# %%
# Final plot showing the best-fit line along with the data points

# Generate a range of x values for the line
x_range = np.linspace(0, 4, 100)
y_pred = optimal_w0 + optimal_w1 * x_range

# Plot the three data points
plt.figure(figsize=(8, 6))
plt.scatter(x_data, y_data, color='red', label='Data Points')

# Plot the best-fit line
plt.plot(x_range, y_pred, color='blue', label=f'Best Fit Line: y = {optimal_w0:.2f} + {optimal_w1:.2f}x')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Fitting Two Parameters to Three Data Points')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Read the text below. Work through all of the details below on the whiteboard with your group. Make sure everyone in your group completely understands all aspect of this. Find an instructor if you have any questions!!
#
# - Put a detailed summary of your discussion in a markdown cell and confirm that everyone in your group understands this.

# %% [markdown]
# <h5 style="font-family: 'Georgia', serif; color: #FFA500;">Gradient Descent and Partial Derivatives</h5>
#
#
# We’ve seen how **gradient descent** helps us minimize the loss function by iteratively updating the parameters $w_0$ and $w_1$. But how does this process actually work?
#
# At each step of gradient descent, we compute the **partial derivatives** of the loss function with respect to $w_0$ and $w_1$. These partial derivatives tell us the direction in which the loss function is increasing. By moving in the opposite direction of the gradient, we ensure that the loss function decreases, allowing us to move closer to the minimum.
#
# The loss function for linear regression is:
#
# $$ L(w_0, w_1) = \sum_{i=1}^{n} \left( y_i - (w_0 + w_1 \cdot x_i) \right)^2 $$
#
# To minimize this, we compute the partial derivatives:
#
# $$ \frac{\partial L}{\partial w_0} = \frac{-2}{n} \sum_{i=1}^{n} \left( y_i - (w_0 + w_1 \cdot x_i) \right) $$
#
# $$ \frac{\partial L}{\partial w_1} = \frac{-2}{n} \sum_{i=1}^{n} \left( y_i - (w_0 + w_1 \cdot x_i) \right) \cdot x_i .$$
#
# Be absolutely sure everyone in your group can derive these and understands what they mean and are used for. Confirm below that everyone in your group studied this and understands it; if anyone is confused -- no problem -- write about what is confusing.
#
# These derivatives give us the gradient, which we use to update $w_0$ and $w_1$ (these are not real equal signs: they are like update equations you would have in Python):
#
# $$ w_0 = w_0 - \alpha \cdot \frac{\partial L}{\partial w_0}, $$
#
# $$ w_1 = w_1 - \alpha \cdot \frac{\partial L}{\partial w_1} ,$$
#
# where $ \alpha $ is the learning rate that controls how large the update steps are.
